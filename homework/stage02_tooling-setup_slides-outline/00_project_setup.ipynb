# %% [markdown]
# # Please note:
# If you encounter any issues related to file paths, make sure to open the file located at the following path:
# `/Users/fd/gitlocal/bootcamp_mingjia_jin/project/notebooks` — the file name should match.
#
# All data files and Python functions can be found under the corresponding `/data` and `/src` folders within:
# `/Users/fd/gitlocal/bootcamp_mingjia_jin/project`.

# %% [markdown]
# # Environment & Config Check

# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # go one level up so src/ is visible

from src.config import load_env, get_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys, os
#       2 sys.path.append(os.path.abspath(".."))  # go one level up so src/ is visible
# ----> 4 from src.config import load_env, get_key
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.config import load_env, get_key
import numpy as np

# Load .env variables
load_env()

# Check API_KEY
print("API_KEY present:", get_key("API_KEY") is not None)

# NumPy small test
arr = np.array([1, 2, 3])
print("Array doubled:", arr * 2)
# Out:
# API_KEY present: True
# Array doubled: [2 4 6]
